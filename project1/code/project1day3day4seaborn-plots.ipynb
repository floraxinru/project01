# %%
#try to make better plots using seaborn:
#also: stations data, try to plot stations geographically - which package to use? Plotly? GeoJSON, GeoPandas

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from sklearn import datasets


# You can configure the format of the images: ‘png’, ‘retina’, ‘jpeg’, ‘svg’, ‘pdf’.
# %config InlineBackend.figure_format = 'svg'
# this statement allows the visuals to render within your Jupyter Notebook
# %matplotlib inline

# %%
#day4 horizontal bar plots for new net weekly data in seaborn

# %%
#horizontal bar plot
f, ax = plt.subplots(figsize=(6, 15))

# %% [markdown]
# ### possible plots:
# * 1 basic: histogram of top stations for a particular week:
# x=stations, y=counts
#
# * 2 bar plot: y-weekly net counts, x-station names (top 3 or top5?) **

# %%
# seaborn histogram
# let's load the data and store it in a Pandas DataFrame

sns.distplot(data['sepal length (cm)'], kde=False,bins=8,norm_hist=True); #how to change transparecy?

# %%
#same example plot in pandas:
# let's load the data and store it in a Pandas DataFrame
iris = datasets.load_iris()
data = pd.DataFrame(iris.data[:, :4],columns = iris.feature_names)
data['target'] = iris.target # 0-'setosa', 1-'versicolor', 2-'virginica'
data.target.replace(to_replace=[0,1,2], value=iris.target_names, inplace=True)

plt.xlabel('Station Names',fontsize = 12, family='sans-serif',color='black')
plt.ylabel('Net Weekly Counts',fontsize = 12, family='sans-serif',color='black');
plt.title('Weekly Counts of Top Stations', fontsize = 20, family='sans-serif', weight = 'bold', fontdict=None, loc='center', pad=None)
'''Can further customize font of title using fontdict in pandas/matplotlib:
fontdict : dict
    A dictionary controlling the appearance of the title text,
    the default `fontdict` is::

       {'fontsize': rcParams['axes.titlesize'],
        'fontweight' : rcParams['axes.titleweight'],
        'verticalalignment': 'baseline',
        'horizontalalignment': loc}
        '''

plt.hist(data['sepal length (cm)'],bins = 8);

# %%
#horizontal bar plot in sns
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(10, 10))
# Load the dataset
data = sns.load_dataset("car_crashes").sort_values("total", ascending=False)

# Plot the total crashes
sns.set_color_codes("pastel") #'deep' for darker colour, 'pastel' for light blue
sns.barplot(x="total", y="abbrev", data=data, 
             color="b") #x and y are axes names here   #label="Total"

#overlapping second set of data and colours:
# Plot the crashes where alcohol was involved
#sns.set_color_codes("muted")
#sns.barplot(x="alcohol", y="abbrev", data=crashes,
#           label="Alcohol-involved", color="b")

# Add a legend and informative axis label
#ax.legend(ncol=2, loc="lower right", frameon=False) #may not need
ax.set(xlim=(0, 15), ylabel="Stations",
       xlabel="Net weekly counts", )
sns.despine(left=False, bottom=False)

# %%
#matplotlib grouped bar chart, decided

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# You can configure the format of the images: ‘png’, ‘retina’, ‘jpeg’, ‘svg’, ‘pdf’.
# %config InlineBackend.figure_format = 'svg'
# this statement allows the visuals to render within your Jupyter Notebook
# %matplotlib inline 


labels = ['G1', 'G2', 'G3', 'G4', 'G5']
stn_1 = [20, 34, 30, 35, 27]
stn_2 = [25, 32, 34, 20, 25]
stn_3 = [25, 32, 35, 24, 39]

x = np.arange(len(labels))  # the label locations
width = 0.33  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width, men_means, width, label='Station1') #with 2 bars, x+/- width/2
rects2 = ax.bar(x, women_means, width, label='Station2')
rects3 = ax.bar(x + width, women_means, width, label='Station3')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Weeks')
ax.set_ylabel('Counts Per Week')
ax.set_title('Net Weekly Counts by Station')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend() #more controls, label indv elements?


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)
autolabel(rects3)

fig.tight_layout(w_pad=1.02)
'''
    pad: Padding between the figure edge and the edges of subplots,
    as a fraction of the font size.
    
default padding =1.08

    h_pad, w_pad: Padding (height/width) between edges of adjacent subplots,
    as a fraction of the font size.  Defaults to *pad*.

    66     pad_inches = pad * font_size_inches
     67     if h_pad is not None:
---> 68         vpad_inches = h_pad * font_size_inches
     69     else:
     70         vpad_inches = pad_inches
'''

plt.show()

# %% [markdown]
# (y=net weekly counts, x=different weeks to compare stations (matplotlib?) -- not useful!
# Better to get avg net weekly traffic to compare with top 3)

# %%
#from day 2 matplotlib plot
data_x = np.arange(7) #days of the week for one station over multiple weeks (rainbow band)
data_y = np.random.randint(500,1000,7) # random integer number between 0 and 9 (10 is excluded)
plt.plot(data_x,data_y);

# %%
counts = np.random.randint(100)
days_wk = ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']
data = pd.DataFrame(values, dates, columns=["A", "B", "C", "D", "E", "F", "G"])
data = data.rolling(7).mean()

# %%
sns.set(style="whitegrid")

rs = np.random.randint(100)
values = rs.randn(365, 7).cumsum(axis=0)
dates = pd.date_range("1 1 2016", periods=365, freq="D") #Returns a fixed frequency DatetimeIndex.
data = pd.DataFrame(values, dates, columns=["A", "B", "C", "D", "E", "F", "G"])
data = data.rolling(7).mean()

sns.lineplot(data=data, palette="tab10", linewidth=2.5);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-b3fc70dfcc7f> in <module>
#       7 data = data.rolling(7).mean()
#       8
# ----> 9 sns.lineplot(data=data, palette="tab10", linewidth=2.5);
#
# /Library/anaconda/envs/metis/lib/python3.7/site-packages/seaborn/relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, sort, err_style, err_kws, legend, ax, **kwargs)
#    1076         dashes=dashes, markers=markers, style_order=style_order,
#    1077         units=units, estimator=estimator, ci=ci, n_boot=n_boot,
# -> 1078         sort=sort, err_style=err_style, err_kws=err_kws, legend=legend,
#    1079     )
#    1080
#
# ...

# %%
#matplotlib dummy plot from day2: 
'''
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# You can configure the format of the images: ‘png’, ‘retina’, ‘jpeg’, ‘svg’, ‘pdf’.
# %config InlineBackend.figure_format = 'svg'
# this statement allows the visuals to render within your Jupyter Notebook
# %matplotlib inline
---
data_x = np.arange(7) #days of the week for one station over multiple weeks (rainbow band)
data_y = np.random.randint(500,1000,7) # random integer number between 0 and 9 (10 is excluded)
#first week
plt.plot(data_x,data_y);
---
#second week
data_x1 = np.arange(7) #days of the week for one station over multiple weeks (rainbow band)
data_y1 = np.random.randint(500,1000,7) # random integer number between 0 and 9 (10 is excluded)
#third week
data_x2 = np.arange(7) #days of the week for one station over multiple weeks (rainbow band)
data_y2 = np.random.randint(500,1000,7) # random integer number between 0 and 9 (10 is excluded)
---

plt.plot(data_x,data_y);
#plt.grid()
ticks_x = np.linspace(0, 7, 8) #8 tick marks between 0 and 7, counting 0 as one tick?
station_names = ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']
plt.xticks(ticks_x, station_names, fontsize = '10', family = 'sans-serif', rotation=40, color='orange');
plt.title('Weekly Commute Numbers',fontsize = 25,style='italic',weight='bold', color='blue');
plt.xlabel('Days of the Week', fontsize = 15, weight = 'bold', family = 'sans-serif', color='black')
plt.ylabel('Daily Count',fontsize = 15, weight = 'bold', family = 'sans-serif',color='black');

plt.plot(data_x1,data_y1);
plt.plot(data_x2,data_y2);

plt.legend(['Week1','Week2','Week3'],shadow = True, loc = 0);

'''
